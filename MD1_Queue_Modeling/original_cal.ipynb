# %%
from mytypes import Queue
import random
import numpy as np
import pandas as pd

# %%
# A class to represent a single customer in an M/D/1 queue simulation.
# Each customer has three attributes:
#
#  - cid: A customer identifier (can be anything, but we will use consecutive integers)
#  - arrival_time: The time at which the customer arrived at the queue
#  - departure_time: The time at which the customer departed the queue
class Customer(object):
    CUSTOMER_ID = 0

    def __init__(self, arrival_time):
        Customer.CUSTOMER_ID += 1
        self.cid = Customer.CUSTOMER_ID
        self.arrival_time = arrival_time
        self.departure_time = None
        
    @property
    def wait(self):
        if self.departure_time is None:
            return None
        else:
            return self.departure_time - self.arrival_time
        
    def __str__(self):
        return "Customer({}, {})".format(self.cid, self.arrival_time)
    
    def __repr__(self):
        return str(self)

# %%
import random

# simulate_md1: Simulates an M/D/1 queue.
#
# In an M/D/1 queue que have:
#   
# - Arrivals follow a Markov process (M)
# - The time to service each customer is deterministic (D)
# - There is only one server (1)
#
# The function takes three parameters (plus one optional parameter)
#
# - lambd: The simulation uses an exponential distribution to determine
#          the arrival time of the next customer. This parameters is the
#          lambda parameter to an exponential distribution (specifically,
#          Python's random.expovariate)
# - mu: The rate at which customers are serviced. The larger this value is,
#       the more customers will be serviced per unit of time
# - max_time: The maximum time of the simulation
# - verbosity (optional): Can be 0 (no output), 1 (print state of the queue
#                         at each time), or 2 (same as 1, but also print when
#                         each customer arrives and departs)
#
# The function returns two lists: one with all the customers that were served
# during the simulation, and one with all the customers that were yet to be
# served when the simulation ended.
#
def simulate_md1(lambd, mu, max_time, verbosity = 0):
    md1 = Queue()
    L_array = []

    # Our return values: the list of customers that have been
    # served, and the list of customers that haven't been served
    served_customers = []
    unserved_customers = []
    
    # The type of simulation we have implemented in this function
    # is known as a "discrete event simulation"
    # (https://en.wikipedia.org/wiki/Discrete_event_simulation), where
    # we simulate a discrete sequence of events: customer arrivals
    # and customer departures. So, we only need to keep track of when 
    # the next arrival and the next departure will take place (because 
    # nothing interesting happens between those two types of events). 
    # Then, in each step of the simulation, we simply advance the 
    # simulation clock to earliest next event. Note that, because
    # we have a single server, this can be easily done with just
    # two variables.

    next_arrival = random.expovariate(lambd)
    next_service = next_arrival + 1/mu
        
    # We initialize the simulation's time to the earliest event:
    # the next arrival time
    t = next_arrival
    
    while t < max_time:

        # Process a new arrival
        if t == next_arrival:
            customer = Customer(arrival_time = t)
            md1.enqueue(customer)

            if verbosity >= 2:
                print("{:10.2f}: Customer {} arrives".format(t, customer.cid))

            next_arrival = t + random.expovariate(lambd)
            
        # The customer at the head of the queue has been served
        if t == next_service:
            done_customer = md1.dequeue()
            done_customer.departure_time = t
            
            served_customers.append(done_customer)

            if verbosity >= 2:
                print("{:10.2f}: Customer {} departs".format(t, done_customer.cid))            
            
            if md1.is_empty():
                # The next service time will be 1/mu after the next arrival
                next_service = next_arrival + 1/mu
            else:
                # We start serving the next customer, so the next service time
                # will be 1/mu after the current time.
                next_service = t + 1/mu
            
        if verbosity >= 1:
            print("{:10.2f}: {}".format(t, "#"*md1.length))
            L_array.append(md1.length)
            
        # Advance the simulation clock to the next event
        t = min(next_arrival, next_service)
        
    # Any remaining customers in the queue haven't been served
    while not md1.is_empty():
        unserved_customers.append(md1.dequeue())
        
    return L_array

# %%
simulate_md1(0.167, 0.15, 100, verbosity=2)
# Out:
#       3.72: Customer 1 arrives
#       3.72: #
#       7.10: Customer 2 arrives
#       7.10: ##
#      10.39: Customer 1 departs
#      10.39: #
#      11.01: Customer 3 arrives
#      11.01: ##
#      15.21: Customer 4 arrives
#      15.21: ###
#      17.06: Customer 2 departs
#      17.06: ##
#      23.72: Customer 3 departs
#      23.72: #
#      30.39: Customer 4 departs
#      30.39:
#      31.07: Customer 5 arrives
#      31.07: #
#      37.74: Customer 5 departs
#      37.74:
#      43.00: Customer 6 arrives
#      43.00: #
#      44.31: Customer 7 arrives
#      44.31: ##
#      49.66: Customer 6 departs
#      49.66: #
#      53.90: Customer 8 arrives
#      53.90: ##
#      55.55: Customer 9 arrives
#      55.55: ###
#      56.33: Customer 7 departs
#      56.33: ##
#      57.22: Customer 10 arrives
#      57.22: ###
#      57.23: Customer 11 arrives
#      57.23: ####
#      57.75: Customer 12 arrives
#      57.75: #####
#      63.00: Customer 8 departs
#      63.00: ####
#      69.66: Customer 9 departs
#      69.66: ###
#      73.49: Customer 13 arrives
#      73.49: ####
#      74.61: Customer 14 arrives
#      74.61: #####
#      76.33: Customer 10 departs
#      76.33: ####
#      83.00: Customer 11 departs
#      83.00: ###
#      84.30: Customer 15 arrives
#      84.30: ####
#      85.03: Customer 16 arrives
#      85.03: #####
#      89.24: Customer 17 arrives
#      89.24: ######
#      89.66: Customer 12 departs
#      89.66: #####
#      91.29: Customer 18 arrives
#      91.29: ######
#      91.61: Customer 19 arrives
#      91.61: #######
#      91.99: Customer 20 arrives
#      91.99: ########
#      93.34: Customer 21 arrives
#      93.34: #########
#      93.87: Customer 22 arrives
#      93.87: ##########
#      96.33: Customer 13 departs
#      96.33: #########
# [1,
#  2,
#  1,
#  2,
#  3,
#  2,
#  1,
#  0,
#  1,
#  0,
#  1,
#  2,
#  1,
#  2,
#  3,
#  2,
#  3,
#  4,
#  5,
#  4,
#  3,
#  4,
#  5,
#  4,
#  3,
#  4,
#  5,
#  6,
#  5,
#  6,
#  7,
#  8,
#  9,
#  10,
#  9]

# %%
#loop through 9 different cases and record the results
result_df = pd.DataFrame(columns = ['n', 'lambda', 'mean', 'variance'])
j = 0
L_array = []
full_L_array = []


for lambd in [1.1]:
    for n in [1000]:
        L_array = []
        full_L_array = []
        for i in range(10):
            L_array = simulate_md1(lambd, 1, n, verbosity=2)
            #print(L_array)
            #print('current run' + str(i))
            full_L_array.extend(L_array)
            #print(full_L_array)
        mean_L = np.mean(full_L_array)
        var_L = np.var(full_L_array)
        #new_row = pd.DataFrame([str(n), str(lambd), mean_L, var_L])
        rows = [n, lambd, mean_L, var_L]
        result_df.loc[j] = rows
        #result_df.append(new_row)
        print(str(n), str(lambd), mean_L, var_L)
        j+=1
        #df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'))
# Out:
#       1.27: Customer 22070 arrives
#       1.27: #
#       1.39: Customer 22071 arrives
#       1.39: ##
#       1.41: Customer 22072 arrives
#       1.41: ###
#       2.27: Customer 22070 departs
#       2.27: ##
#       3.27: Customer 22071 departs
#       3.27: #
#       3.55: Customer 22073 arrives
#       3.55: ##
#       3.74: Customer 22074 arrives
#       3.74: ###
#       4.27: Customer 22072 departs
#       4.27: ##
#       5.25: Customer 22075 arrives
#       5.25: ###
#       5.27: Customer 22073 departs
#       5.27: ##
#       6.27: Customer 22074 departs
#       6.27: #
#       7.10: Customer 22076 arrives
#       7.10: ##
#       7.27: Customer 22075 departs
#       7.27: #
#       7.95: Customer 22077 arrives
#       7.95: ##
#       8.27: Customer 22076 departs
#       8.27: #
#       8.53: Customer 22078 arrives
#       8.53: ##
#       9.27: Customer 22077 departs
#       9.27: #
#       9.45: Customer 22079 arrives
#       9.45: ##
#      10.27: Customer 22078 departs
#      10.27: #
#      11.27: Customer 22079 departs
#      11.27:
#      12.35: Customer 22080 arrives
#      12.35: #
#      13.35: Customer 22080 departs
#      13.35:
#      13.63: Customer 22081 arrives
#      13.63: #
#      14.44: Customer 22082 arrives
#      14.44: ##
#      14.63: Customer 22081 departs
#      14.63: #
#      14.75: Customer 22083 arrives
#      14.75: ##
#      15.14: Customer 22084 arrives
#      15.14: ###
#      15.35: Customer 22085 arrives
#      15.35: ####
#      15.56: Customer 22086 arrives
#      15.56: #####
#      15.63: Customer 22082 departs
#      15.63: ####
#      15.95: Customer 22087 arrives
#      15.95: #####
#      16.63: Customer 22083 departs
#      16.63: ####
#      17.63: Customer 22084 departs
#      17.63: ###
#      18.01: Customer 22088 arrives
#      18.01: ####
#      18.38: Customer 22089 arrives
#      18.38: #####
#      18.63: Customer 22085 departs
#      18.63: ####
#      18.68: Customer 22090 arrives
#      18.68: #####
#      19.63: Customer 22086 departs
#      19.63: ####
#      20.63: Customer 22087 departs
#      20.63: ###
#      20.94: Customer 22091 arrives
#      20.94: ####
#      21.63: Customer 22088 departs
#      21.63: ###
#      22.39: Customer 22092 arrives
#      22.39: ####
#      22.63: Customer 22089 departs
#      22.63: ###
#      23.63: Customer 22090 departs
#      23.63: ##
#      23.67: Customer 22093 arrives
#      23.67: ###
#      24.35: Customer 22094 arrives
#      24.35: ####
#      24.63: Customer 22091 departs
#      24.63: ###
#      25.29: Customer 22095 arrives
#      25.29: ####
#      25.63: Customer 22092 departs
#      25.63: ###
#      26.63: Customer 22093 departs
#      26.63: ##
#      27.63: Customer 22094 departs
#      27.63: #
#      28.41: Customer 22096 arrives
#      28.41: ##
#      28.57: Customer 22097 arrives
#      28.57: ###
#      28.63: Customer 22095 departs
#      28.63: ##
#      29.63: Customer 22096 departs
#      29.63: #
#      30.29: Customer 22098 arrives
#      30.29: ##
#      30.38: Customer 22099 arrives
#      30.38: ###
#      30.63: Customer 22097 departs
#      30.63: ##
#      30.93: Customer 22100 arrives
#      30.93: ###
#      31.42: Customer 22101 arrives
#      31.42: ####
#      31.63: Customer 22098 departs
#      31.63: ###
#      32.20: Customer 22102 arrives
#      32.20: ####
#      32.63: Customer 22099 departs
#      32.63: ###
#      33.11: Customer 22103 arrives
#      33.11: ####
#      33.63: Customer 22100 departs
#      33.63: ###
#      33.72: Customer 22104 arrives
#      33.72: ####
#      34.44: Customer 22105 arrives
#      34.44: #####
#      34.63: Customer 22101 departs
#      34.63: ####
#      35.00: Customer 22106 arrives
#      35.00: #####
#      35.15: Customer 22107 arrives
#      35.15: ######
#      35.63: Customer 22102 departs
#      35.63: #####
#      36.63: Customer 22103 departs
#      36.63: ####
#      36.66: Customer 22108 arrives
#      36.66: #####
#      37.44: Customer 22109 arrives
#      37.44: ######
#      37.63: Customer 22104 departs
#      37.63: #####
#      37.71: Customer 22110 arrives
#      37.71: ######
#      38.63: Customer 22105 departs
#      38.63: #####
#      38.93: Customer 22111 arrives
#      38.93: ######
#      39.15: Customer 22112 arrives
#      39.15: #######
#      39.63: Customer 22106 departs
#      39.63: ######
#      40.63: Customer 22107 departs
#      40.63: #####
#      40.78: Customer 22113 arrives
#      40.78: ######
#      41.08: Customer 22114 arrives
#      41.08: #######
#      41.63: Customer 22108 departs
#      41.63: ######
#      42.58: Customer 22115 arrives
#      42.58: #######
#      42.63: Customer 22109 departs
#      42.63: ######
#      43.08: Customer 22116 arrives
#      43.08: #######
#      43.63: Customer 22110 departs
#      43.63: ######
#      44.59: Customer 22117 arrives
#      44.59: #######
#      44.63: Customer 22111 departs
#      44.63: ######
#      44.73: Customer 22118 arrives
#      44.73: #######
#      45.26: Customer 22119 arrives
#      45.26: ########
#      45.63: Customer 22112 departs
#      45.63: #######
#      45.72: Customer 22120 arrives
#      45.72: ########
#      46.06: Customer 22121 arrives
#      46.06: #########
#      46.63: Customer 22113 departs
#      46.63: ########
#      46.86: Customer 22122 arrives
#      46.86: #########
#      46.99: Customer 22123 arrives
#      46.99: ##########
#      47.63: Customer 22114 departs
#      47.63: #########
#      48.63: Customer 22115 departs
#      48.63: ########
#      49.63: Customer 22116 departs
#      49.63: #######
#      49.71: Customer 22124 arrives
#      49.71: ########
#      50.30: Customer 22125 arrives
#      50.30: #########
#      50.63: Customer 22117 departs
#      50.63: ########
#      50.92: Customer 22126 arrives
#      50.92: #########
#      51.63: Customer 22118 departs
#      51.63: ########
#      52.22: Customer 22127 arrives
#      52.22: #########
#      52.63: Customer 22119 departs
#      52.63: ########
#      52.87: Customer 22128 arrives
#      52.87: #########
#      53.32: Customer 22129 arrives
#      53.32: ##########
#      53.63: Customer 22120 departs
#      53.63: #########
#      54.53: Customer 22130 arrives
#      54.53: ##########
#      54.63: Customer 22121 departs
#      54.63: #########
#      54.88: Customer 22131 arrives
#      54.88: ##########
#      55.25: Customer 22132 arrives
#      55.25: ###########
#      55.63: Customer 22122 departs
#      55.63: ##########
#      55.69: Customer 22133 arrives
#      55.69: ###########
#      55.86: Customer 22134 arrives
#      55.86: ############
#      56.63: Customer 22123 departs
#      56.63: ###########
#      56.71: Customer 22135 arrives
#      56.71: ############
#      57.63: Customer 22124 departs
#      57.63: ###########
#      58.07: Customer 22136 arrives
#      58.07: ############
#      58.63: Customer 22125 departs
#      58.63: ###########
#      59.63: Customer 22126 departs
#      59.63: ##########
#      60.63: Customer 22127 departs
#      60.63: #########
#      61.63: Customer 22128 departs
#      61.63: ########
#      62.12: Customer 22137 arrives
#      62.12: #########
#      62.63: Customer 22129 departs
#      62.63: ########
#      62.71: Customer 22138 arrives
#      62.71: #########
#      63.00: Customer 22139 arrives
#      63.00: ##########
#      63.63: Customer 22130 departs
#      63.63: #########
#      64.52: Customer 22140 arrives
#      64.52: ##########
#      64.63: Customer 22131 departs
#      64.63: #########
#      65.63: Customer 22132 departs
#      65.63: ########
#      66.63: Customer 22133 departs
#      66.63: #######
#      67.47: Customer 22141 arrives
#      67.47: ########
#      67.63: Customer 22134 departs
#      67.63: #######
#      68.63: Customer 22135 departs
#      68.63: ######
#      69.63: Customer 22136 departs
#      69.63: #####
#      69.98: Customer 22142 arrives
#      69.98: ######
#      70.63: Customer 22137 departs
#      70.63: #####
#      70.87: Customer 22143 arrives
#      70.87: ######
#      71.45: Customer 22144 arrives
#      71.45: #######
#      71.63: Customer 22138 departs
#      71.63: ######
#      71.86: Customer 22145 arrives
#      71.86: #######
#      72.25: Customer 22146 arrives
#      72.25: ########
#      72.63: Customer 22139 departs
#      72.63: #######
#      72.98: Customer 22147 arrives
#      72.98: ########
#      73.63: Customer 22140 departs
#      73.63: #######
#      74.43: Customer 22148 arrives
#      74.43: ########
#      74.44: Customer 22149 arrives
#      74.44: #########
#      74.63: Customer 22141 departs
#      74.63: ########
#      75.63: Customer 22142 departs
#      75.63: #######
#      76.44: Customer 22150 arrives
#      76.44: ########
#      76.62: Customer 22151 arrives
#      76.62: #########
#      76.63: Customer 22143 departs
#      76.63: ########
#      77.63: Customer 22144 departs
#      77.63: #######
#      77.71: Customer 22152 arrives
#      77.71: ########
#      78.63: Customer 22145 departs
#      78.63: #######
#      78.91: Customer 22153 arrives
#      78.91: ########
#      79.27: Customer 22154 arrives
#      79.27: #########
#      79.63: Customer 22146 departs
#      79.63: ########
#      80.29: Customer 22155 arrives
#      80.29: #########
#      80.63: Customer 22147 departs
#      80.63: ########
#      81.63: Customer 22148 departs
#      81.63: #######
#      82.63: Customer 22149 departs
#      82.63: ######
#      83.63: Customer 22150 departs
#      83.63: #####
#      83.76: Customer 22156 arrives
#      83.76: ######
#      83.99: Customer 22157 arrives
#      83.99: #######
#      84.23: Customer 22158 arrives
#      84.23: ########
#      84.63: Customer 22151 departs
#      84.63: #######
#      85.63: Customer 22152 departs
#      85.63: ######
#      85.84: Customer 22159 arrives
#      85.84: #######
#      86.63: Customer 22153 departs
#      86.63: ######
#      87.63: Customer 22154 departs
#      87.63: #####
#      87.83: Customer 22160 arrives
#      87.83: ######
#      88.50: Customer 22161 arrives
#      88.50: #######
#      88.63: Customer 22155 departs
#      88.63: ######
#      89.16: Customer 22162 arrives
#      89.16: #######
#      89.63: Customer 22156 departs
#      89.63: ######
#      90.17: Customer 22163 arrives
#      90.17: #######
#      90.63: Customer 22157 departs
#      90.63: ######
#      90.92: Customer 22164 arrives
#      90.92: #######
#      91.63: Customer 22158 departs
#      91.63: ######
#      92.63: Customer 22159 departs
#      92.63: #####
#      93.01: Customer 22165 arrives
#      93.01: ######
#      93.63: Customer 22160 departs
#      93.63: #####
#      94.12: Customer 22166 arrives
#      94.12: ######
#      94.19: Customer 22167 arrives
#      94.19: #######
#      94.63: Customer 22161 departs
#      94.63: ######
#      95.56: Customer 22168 arrives
#      95.56: #######
#      95.63: Customer 22162 departs
#      95.63: ######
#      95.83: Customer 22169 arrives
#      95.83: #######
#      96.56: Customer 22170 arrives
#      96.56: ########
#      96.63: Customer 22163 departs
#      96.63: #######
#      97.63: Customer 22164 departs
#      97.63: ######
#      97.63: Customer 22171 arrives
#      97.63: #######
#      97.94: Customer 22172 arrives
#      97.94: ########
#      98.63: Customer 22165 departs
#      98.63: #######
#      99.62: Customer 22173 arrives
#      99.62: ########
#      99.63: Customer 22166 departs
#      99.63: #######
#      99.67: Customer 22174 arrives
#      99.67: ########
#     100.63: Customer 22167 departs
#     100.63: #######
#     101.63: Customer 22168 departs
#     101.63: ######
#     102.42: Customer 22175 arrives
#     102.42: #######
#     102.63: Customer 22169 departs
#     102.63: ######
#     103.63: Customer 22170 departs
#     103.63: #####
#     104.40: Customer 22176 arrives
#     104.40: ######
#     104.63: Customer 22171 departs
#     104.63: #####
#     104.96: Customer 22177 arrives
#     104.96: ######
#     105.02: Customer 22178 arrives
#     105.02: #######
#     105.06: Customer 22179 arrives
#     105.06: ########
#     105.17: Customer 22180 arrives
#     105.17: #########
#     105.39: Customer 22181 arrives
#     105.39: ##########
#     105.63: Customer 22172 departs
#     105.63: #########
#     106.12: Customer 22182 arrives
#     106.12: ##########
#     106.63: Customer 22173 departs
#     106.63: #########
#     106.73: Customer 22183 arrives
#     106.73: ##########
#     107.33: Customer 22184 arrives
#     107.33: ###########
#     107.42: Customer 22185 arrives
#     107.42: ############
#     107.63: Customer 22174 departs
#     107.63: ###########
#     108.63: Customer 22175 departs
#     108.63: ##########
#     109.23: Customer 22186 arrives
#     109.23: ###########
#     109.63: Customer 22176 departs
#     109.63: ##########
#     110.36: Customer 22187 arrives
#     110.36: ###########
#     110.63: Customer 22177 departs
#     110.63: ##########
#     111.63: Customer 22178 departs
#     111.63: #########
#     112.63: Customer 22179 departs
#     112.63: ########
#     113.63: Customer 22180 departs
#     113.63: #######
#     113.79: Customer 22188 arrives
#     113.79: ########
#     114.15: Customer 22189 arrives
#     114.15: #########
#     114.30: Customer 22190 arrives
#     114.30: ##########
#     114.41: Customer 22191 arrives
#     114.41: ###########
#     114.63: Customer 22181 departs
#     114.63: ##########
#     115.63: Customer 22182 departs
#     115.63: #########
#     116.26: Customer 22192 arrives
#     116.26: ##########
#     116.63: Customer 22183 departs
#     116.63: #########
#     117.55: Customer 22193 arrives
#     117.55: ##########
#     117.63: Customer 22184 departs
#     117.63: #########
#     117.76: Customer 22194 arrives
#     117.76: ##########
#     117.83: Customer 22195 arrives
#     117.83: ###########
#     117.99: Customer 22196 arrives
#     117.99: ############
#     118.63: Customer 22185 departs
#     118.63: ###########
#     119.63: Customer 22186 departs
#     119.63: ##########
#     120.54: Customer 22197 arrives
#     120.54: ###########
#     120.63: Customer 22187 departs
#     120.63: ##########
#     121.63: Customer 22188 departs
#     121.63: #########
#     121.73: Customer 22198 arrives
#     121.73: ##########
#     121.97: Customer 22199 arrives
#     121.97: ###########
#     122.45: Customer 22200 arrives
#     122.45: ############
#     122.63: Customer 22189 departs
#     122.63: ###########
#     123.02: Customer 22201 arrives
#     123.02: ############
#     123.63: Customer 22190 departs
#     123.63: ###########
#     123.96: Customer 22202 arrives
#     123.96: ############
#     124.63: Customer 22191 departs
#     124.63: ###########
#     125.63: Customer 22192 departs
#     125.63: ##########
#     125.75: Customer 22203 arrives
#     125.75: ###########
#     125.89: Customer 22204 arrives
#     125.89: ############
#     126.20: Customer 22205 arrives
#     126.20: #############
#     126.60: Customer 22206 arrives
#     126.60: ##############
#     126.63: Customer 22193 departs
#     126.63: #############
#     127.12: Customer 22207 arrives
#     127.12: ##############
#     127.63: Customer 22194 departs
#     127.63: #############
#     128.39: Customer 22208 arrives
#     128.39: ##############
#     128.52: Customer 22209 arrives
#     128.52: ###############
#     128.63: Customer 22195 departs
#     128.63: ##############
#     129.58: Customer 22210 arrives
#     129.58: ###############
#     129.63: Customer 22196 departs
#     129.63: ##############
#     130.63: Customer 22197 departs
#     130.63: #############
#     131.08: Customer 22211 arrives
#     131.08: ##############
#     131.63: Customer 22198 departs
#     131.63: #############
#     131.79: Customer 22212 arrives
#     131.79: ##############
#     132.63: Customer 22199 departs
#     132.63: #############
#     133.18: Customer 22213 arrives
#     133.18: ##############
#     133.55: Customer 22214 arrives
#     133.55: ###############
#     133.63: Customer 22200 departs
#     133.63: ##############
#     133.65: Customer 22215 arrives
#     133.65: ###############
#     133.98: Customer 22216 arrives
#     133.98: ################
#     134.63: Customer 22201 departs
#     134.63: ###############
#     134.75: Customer 22217 arrives
#     134.75: ################
#     135.37: Customer 22218 arrives
#     135.37: #################
#     135.63: Customer 22202 departs
#     135.63: ################
#     135.79: Customer 22219 arrives
#     135.79: #################
#     136.63: Customer 22203 departs
#     136.63: ################
#     137.42: Customer 22220 arrives
#     137.42: #################
#     137.63: Customer 22204 departs
#     137.63: ################
#     137.80: Customer 22221 arrives
#     137.80: #################
#     137.86: Customer 22222 arrives
#     137.86: ##################
#     138.20: Customer 22223 arrives
#     138.20: ###################
#     138.40: Customer 22224 arrives
#     138.40: ####################
#     138.55: Customer 22225 arrives
#     138.55: #####################
#     138.63: Customer 22205 departs
#     138.63: ####################
#     139.63: Customer 22206 departs
#     139.63: ###################
#     140.19: Customer 22226 arrives
#     140.19: ####################
#     140.40: Customer 22227 arrives
#     140.40: #####################
#     140.63: Customer 22207 departs
#     140.63: ####################
#     141.63: Customer 22208 departs
#     141.63: ###################
#     142.27: Customer 22228 arrives
#     142.27: ####################
#     142.54: Customer 22229 arrives
#     142.54: #####################
#     142.63: Customer 22209 departs
#     142.63: ####################
#     142.95: Customer 22230 arrives
#     142.95: #####################
#     143.13: Customer 22231 arrives
#     143.13: ######################
#     143.63: Customer 22210 departs
#     143.63: #####################
#     144.63: Customer 22211 departs
#     144.63: ####################
#     145.63: Customer 22212 departs
#     145.63: ###################
#     146.63: Customer 22213 departs
#     146.63: ##################
#     147.63: Customer 22214 departs
#     147.63: #################
#     147.72: Customer 22232 arrives
#     147.72: ##################
#     148.26: Customer 22233 arrives
#     148.26: ###################
#     148.63: Customer 22215 departs
#     148.63: ##################
#     148.97: Customer 22234 arrives
#     148.97: ###################
#     149.22: Customer 22235 arrives
#     149.22: ####################
#     149.52: Customer 22236 arrives
#     149.52: #####################
#     149.63: Customer 22216 departs
#     149.63: ####################
#     149.74: Customer 22237 arrives
#     149.74: #####################
#     149.86: Customer 22238 arrives
#     149.86: ######################
#     150.63: Customer 22217 departs
#     150.63: #####################
#     151.63: Customer 22218 departs
#     151.63: ####################
#     152.63: Customer 22219 departs
#     152.63: ###################
#     153.63: Customer 22220 departs
#     153.63: ##################
#     154.63: Customer 22221 departs
#     154.63: #################
#     155.63: Customer 22222 departs
#     155.63: ################
#     155.65: Customer 22239 arrives
#     155.65: #################
#     156.63: Customer 22223 departs
#     156.63: ################
#     156.75: Customer 22240 arrives
#     156.75: #################
#     157.63: Customer 22224 departs
#     157.63: ################
#     158.63: Customer 22225 departs
#     158.63: ###############
#     159.63: Customer 22226 departs
#     159.63: ##############
#     159.97: Customer 22241 arrives
#     159.97: ###############
#     160.46: Customer 22242 arrives
#     160.46: ################
#     160.63: Customer 22227 departs
#     160.63: ###############
#     161.50: Customer 22243 arrives
#     161.50: ################
#     161.63: Customer 22228 departs
#     161.63: ###############
#     162.63: Customer 22229 departs
#     162.63: ##############
#     162.67: Customer 22244 arrives
#     162.67: ###############
#     163.20: Customer 22245 arrives
#     163.20: ################
#     163.63: Customer 22230 departs
#     163.63: ###############
#     163.99: Customer 22246 arrives
#     163.99: ################
#     164.00: Customer 22247 arrives
#     164.00: #################
#     164.58: Customer 22248 arrives
#     164.58: ##################
#     164.63: Customer 22231 departs
#     164.63: #################
#     164.76: Customer 22249 arrives
#     164.76: ##################
#     165.63: Customer 22232 departs
#     165.63: #################
#     166.63: Customer 22233 departs
#     166.63: ################
#     166.90: Customer 22250 arrives
#     166.90: #################
#     167.63: Customer 22234 departs
#     167.63: ################
#     168.63: Customer 22235 departs
#     168.63: ###############
#     168.99: Customer 22251 arrives
#     168.99: ################
#     169.60: Customer 22252 arrives
#     169.60: #################
#     169.63: Customer 22236 departs
#     169.63: ################
#     169.77: Customer 22253 arrives
#     169.77: #################
#     170.21: Customer 22254 arrives
#     170.21: ##################
#     170.38: Customer 22255 arrives
#     170.38: ###################
#     170.63: Customer 22237 departs
#     170.63: ##################
#     170.77: Customer 22256 arrives
#     170.77: ###################
#     171.63: Customer 22238 departs
#     171.63: ##################
#     172.63: Customer 22239 departs
#     172.63: #################
#     172.65: Customer 22257 arrives
#     172.65: ##################
#     173.63: Customer 22240 departs
#     173.63: #################
#     173.88: Customer 22258 arrives
#     173.88: ##################
#     174.46: Customer 22259 arrives
#     174.46: ###################
#     174.63: Customer 22241 departs
#     174.63: ##################
#     174.63: Customer 22260 arrives
#     174.63: ###################
#     174.90: Customer 22261 arrives
#     174.90: ####################
#     175.63: Customer 22242 departs
#     175.63: ###################
#     176.00: Customer 22262 arrives
#     176.00: ####################
#     176.08: Customer 22263 arrives
#     176.08: #####################
#     176.37: Customer 22264 arrives
#     176.37: ######################
#     176.63: Customer 22243 departs
#     176.63: #####################
#     177.63: Customer 22244 departs
#     177.63: ####################
#     178.39: Customer 22265 arrives
#     178.39: #####################
#     178.57: Customer 22266 arrives
#     178.57: ######################
#     178.58: Customer 22267 arrives
#     178.58: #######################
#     178.63: Customer 22245 departs
#     178.63: ######################
#     179.07: Customer 22268 arrives
#     179.07: #######################
#     179.25: Customer 22269 arrives
#     179.25: ########################
#     179.63: Customer 22246 departs
#     179.63: #######################
#     180.63: Customer 22247 departs
#     180.63: ######################
#     181.08: Customer 22270 arrives
#     181.08: #######################
#     181.63: Customer 22248 departs
#     181.63: ######################
#     182.27: Customer 22271 arrives
#     182.27: #######################
#     182.63: Customer 22249 departs
#     182.63: ######################
#     182.99: Customer 22272 arrives
#     182.99: #######################
#     183.63: Customer 22250 departs
#     183.63: ######################
#     184.63: Customer 22251 departs
#     184.63: #####################
#     184.91: Customer 22273 arrives
#     184.91: ######################
#     185.15: Customer 22274 arrives
#     185.15: #######################
#     185.63: Customer 22252 departs
#     185.63: ######################
#     186.63: Customer 22253 departs
#     186.63: #####################
#     186.82: Customer 22275 arrives
#     186.82: ######################
#     187.01: Customer 22276 arrives
#     187.01: #######################
#     187.63: Customer 22254 departs
#     187.63: ######################
#     187.69: Customer 22277 arrives
#     187.69: #######################
#     188.63: Customer 22255 departs
#     188.63: ######################
#     189.54: Customer 22278 arrives
#     189.54: #######################
#     189.63: Customer 22256 departs
#     189.63: ######################
#     190.38: Customer 22279 arrives
#     190.38: #######################
#     190.63: Customer 22257 departs
#     190.63: ######################
#     190.65: Customer 22280 arrives
#     190.65: #######################
#     190.91: Customer 22281 arrives
#     190.91: ########################
#     191.63: Customer 22258 departs
#     191.63: #######################
#     192.63: Customer 22259 departs
#     192.63: ######################
#     193.63: Customer 22260 departs
#     193.63: #####################
#     194.63: Customer 22261 departs
#     194.63: ####################
#     195.63: Customer 22262 departs
#     195.63: ###################
#     196.63: Customer 22263 departs
#     196.63: ##################
#     197.21: Customer 22282 arrives
#     197.21: ###################
#     197.63: Customer 22264 departs
#     197.63: ##################
#     198.63: Customer 22265 departs
#     198.63: #################
#     199.63: Customer 22266 departs
#     199.63: ################
#     200.16: Customer 22283 arrives
#     200.16: #################
#     200.28: Customer 22284 arrives
#     200.28: ##################
#     200.49: Customer 22285 arrives
#     200.49: ###################
#     200.63: Customer 22267 departs
#     200.63: ##################
#     201.63: Customer 22268 departs
#     201.63: #################
#     201.92: Customer 22286 arrives
#     201.92: ##################
#     202.63: Customer 22269 departs
#     202.63: #################
#     203.63: Customer 22270 departs
#     203.63: ################
#     203.68: Customer 22287 arrives
#     203.68: #################
#     204.03: Customer 22288 arrives
#     204.03: ##################
#     204.63: Customer 22271 departs
#     204.63: #################
#     205.63: Customer 22272 departs
#     205.63: ################
#     205.92: Customer 22289 arrives
#     205.92: #################
#     206.63: Customer 22273 departs
#     206.63: ################
#     207.63: Customer 22274 departs
#     207.63: ###############
#     208.47: Customer 22290 arrives
#     208.47: ################
#     208.63: Customer 22275 departs
#     208.63: ###############
#     208.86: Customer 22291 arrives
#     208.86: ################
#     209.63: Customer 22276 departs
#     209.63: ###############
#     209.84: Customer 22292 arrives
#     209.84: ################
#     210.07: Customer 22293 arrives
#     210.07: #################
#     210.48: Customer 22294 arrives
#     210.48: ##################
#     210.63: Customer 22277 departs
#     210.63: #################
#     211.37: Customer 22295 arrives
#     211.37: ##################
#     211.44: Customer 22296 arrives
#     211.44: ###################
#     211.63: Customer 22278 departs
#     211.63: ##################
#     211.76: Customer 22297 arrives
#     211.76: ###################
#     212.56: Customer 22298 arrives
#     212.56: ####################
#     212.63: Customer 22279 departs
#     212.63: ###################
#     213.63: Customer 22280 departs
#     213.63: ##################
#     214.63: Customer 22281 departs
#     214.63: #################
#     214.71: Customer 22299 arrives
#     214.71: ##################
#     214.79: Customer 22300 arrives
#     214.79: ###################
#     215.54: Customer 22301 arrives
#     215.54: ####################
#     215.63: Customer 22282 departs
#     215.63: ###################
#     215.86: Customer 22302 arrives
#     215.86: ####################
#     216.63: Customer 22283 departs
#     216.63: ###################
#     217.63: Customer 22284 departs
#     217.63: ##################
#     218.63: Customer 22285 departs
#     218.63: #################
#     218.83: Customer 22303 arrives
#     218.83: ##################
#     219.63: Customer 22286 departs
#     219.63: #################
#     219.73: Customer 22304 arrives
#     219.73: ##################
#     220.31: Customer 22305 arrives
#     220.31: ###################
#     220.63: Customer 22287 departs
#     220.63: ##################
#     220.93: Customer 22306 arrives
#     220.93: ###################
#     221.17: Customer 22307 arrives
#     221.17: ####################
#     221.63: Customer 22288 departs
#     221.63: ###################
#     222.07: Customer 22308 arrives
#     222.07: ####################
#     222.63: Customer 22289 departs
#     222.63: ###################
#     223.63: Customer 22290 departs
#     223.63: ##################
#     224.44: Customer 22309 arrives
#     224.44: ###################
#     224.63: Customer 22291 departs
#     224.63: ##################
#     225.03: Customer 22310 arrives
#     225.03: ###################
#     225.39: Customer 22311 arrives
#     225.39: ####################
#     225.63: Customer 22292 departs
#     225.63: ###################
#     225.68: Customer 22312 arrives
#     225.68: ####################
#     226.22: Customer 22313 arrives
#     226.22: #####################
#     226.63: Customer 22293 departs
#     226.63: ####################
#     226.97: Customer 22314 arrives
#     226.97: #####################
#     227.63: Customer 22294 departs
#     227.63: ####################
#     227.89: Customer 22315 arrives
#     227.89: #####################
#     228.62: Customer 22316 arrives
#     228.62: ######################
#     228.63: Customer 22295 departs
#     228.63: #####################
#     229.30: Customer 22317 arrives
#     229.30: ######################
#     229.63: Customer 22296 departs
#     229.63: #####################
#     230.27: Customer 22318 arrives
#     230.27: ######################
#     230.63: Customer 22297 departs
#     230.63: #####################
#     231.63: Customer 22298 departs
#     231.63: ####################
#     232.63: Customer 22299 departs
#     232.63: ###################
#     232.88: Customer 22319 arrives
#     232.88: ####################
#     232.95: Customer 22320 arrives
#     232.95: #####################
#     233.20: Customer 22321 arrives
#     233.20: ######################
#     233.63: Customer 22300 departs
#     233.63: #####################
#     233.68: Customer 22322 arrives
#     233.68: ######################
#     234.09: Customer 22323 arrives
#     234.09: #######################
#     234.63: Customer 22301 departs
#     234.63: ######################
#     234.88: Customer 22324 arrives
#     234.88: #######################
#     235.63: Customer 22302 departs
#     235.63: ######################
#     236.58: Customer 22325 arrives
#     236.58: #######################
#     236.63: Customer 22303 departs
#     236.63: ######################
#     237.54: Customer 22326 arrives
#     237.54: #######################
#     237.63: Customer 22304 departs
#     237.63: ######################
#     238.59: Customer 22327 arrives
#     238.59: #######################
#     238.63: Customer 22305 departs
#     238.63: ######################
#     239.63: Customer 22306 departs
#     239.63: #####################
#     240.56: Customer 22328 arrives
#     240.56: ######################
#     240.63: Customer 22307 departs
#     240.63: #####################
#     241.00: Customer 22329 arrives
#     241.00: ######################
#     241.63: Customer 22308 departs
#     241.63: #####################
#     241.80: Customer 22330 arrives
#     241.80: ######################
#     242.63: Customer 22309 departs
#     242.63: #####################
#     242.96: Customer 22331 arrives
#     242.96: ######################
#     243.36: Customer 22332 arrives
#     243.36: #######################
#     243.63: Customer 22310 departs
#     243.63: ######################
#     243.89: Customer 22333 arrives
#     243.89: #######################
#     244.20: Customer 22334 arrives
#     244.20: ########################
#     244.21: Customer 22335 arrives
#     244.21: #########################
#     244.63: Customer 22311 departs
#     244.63: ########################
#     245.63: Customer 22312 departs
#     245.63: #######################
#     246.24: Customer 22336 arrives
#     246.24: ########################
#     246.63: Customer 22313 departs
#     246.63: #######################
#     247.63: Customer 22314 departs
#     247.63: ######################
#     247.84: Customer 22337 arrives
#     247.84: #######################
#     248.63: Customer 22315 departs
#     248.63: ######################
#     249.63: Customer 22316 departs
#     249.63: #####################
#     250.42: Customer 22338 arrives
#     250.42: ######################
#     250.63: Customer 22317 departs
#     250.63: #####################
#     251.04: Customer 22339 arrives
#     251.04: ######################
#     251.56: Customer 22340 arrives
#     251.56: #######################
#     251.57: Customer 22341 arrives
#     251.57: ########################
#     251.63: Customer 22318 departs
#     251.63: #######################
#     252.39: Customer 22342 arrives
#     252.39: ########################
#     252.63: Customer 22319 departs
#     252.63: #######################
#     252.93: Customer 22343 arrives
#     252.93: ########################
#     252.94: Customer 22344 arrives
#     252.94: #########################
#     252.94: Customer 22345 arrives
#     252.94: ##########################
#     253.14: Customer 22346 arrives
#     253.14: ###########################
#     253.29: Customer 22347 arrives
#     253.29: ############################
#     253.63: Customer 22320 departs
#     253.63: ###########################
#     253.76: Customer 22348 arrives
#     253.76: ############################
#     253.97: Customer 22349 arrives
#     253.97: #############################
#     254.28: Customer 22350 arrives
#     254.28: ##############################
#     254.63: Customer 22321 departs
#     254.63: #############################
#     255.63: Customer 22322 departs
#     255.63: ############################
#     256.08: Customer 22351 arrives
#     256.08: #############################
#     256.26: Customer 22352 arrives
#     256.26: ##############################
#     256.63: Customer 22323 departs
#     256.63: #############################
#     257.63: Customer 22324 departs
#     257.63: ############################
#     257.68: Customer 22353 arrives
#     257.68: #############################
#     258.22: Customer 22354 arrives
#     258.22: ##############################
#     258.63: Customer 22325 departs
#     258.63: #############################
#     259.63: Customer 22326 departs
#     259.63: ############################
#     260.63: Customer 22327 departs
#     260.63: ###########################
#     260.82: Customer 22355 arrives
#     260.82: ############################
#     261.63: Customer 22328 departs
#     261.63: ###########################
#     261.81: Customer 22356 arrives
#     261.81: ############################
#     261.87: Customer 22357 arrives
#     261.87: #############################
#     262.21: Customer 22358 arrives
#     262.21: ##############################
#     262.63: Customer 22329 departs
#     262.63: #############################
#     262.77: Customer 22359 arrives
#     262.77: ##############################
#     263.07: Customer 22360 arrives
#     263.07: ###############################
#     263.18: Customer 22361 arrives
#     263.18: ################################
#     263.37: Customer 22362 arrives
#     263.37: #################################
#     263.63: Customer 22330 departs
#     263.63: ################################
#     263.88: Customer 22363 arrives
#     263.88: #################################
#     264.62: Customer 22364 arrives
#     264.62: ##################################
#     264.63: Customer 22331 departs
#     264.63: #################################
#     265.63: Customer 22332 departs
#     265.63: ################################
#     266.02: Customer 22365 arrives
#     266.02: #################################
#     266.63: Customer 22333 departs
#     266.63: ################################
#     267.63: Customer 22334 departs
#     267.63: ###############################
#     268.11: Customer 22366 arrives
#     268.11: ################################
#     268.50: Customer 22367 arrives
#     268.50: #################################
#     268.63: Customer 22335 departs
#     268.63: ################################
#     269.16: Customer 22368 arrives
#     269.16: #################################
#     269.63: Customer 22336 departs
#     269.63: ################################
#     269.95: Customer 22369 arrives
#     269.95: #################################
#     270.61: Customer 22370 arrives
#     270.61: ##################################
#     270.63: Customer 22337 departs
#     270.63: #################################
#     271.39: Customer 22371 arrives
#     271.39: ##################################
#     271.63: Customer 22338 departs
#     271.63: #################################
#     272.22: Customer 22372 arrives
#     272.22: ##################################
#     272.30: Customer 22373 arrives
#     272.30: ###################################
#     272.63: Customer 22339 departs
#     272.63: ##################################
#     272.85: Customer 22374 arrives
#     272.85: ###################################
#     273.63: Customer 22340 departs
#     273.63: ##################################
#     273.94: Customer 22375 arrives
#     273.94: ###################################
#     273.95: Customer 22376 arrives
#     273.95: ####################################
#     274.63: Customer 22341 departs
#     274.63: ###################################
#     275.63: Customer 22342 departs
#     275.63: ##################################
#     275.83: Customer 22377 arrives
#     275.83: ###################################
#     276.21: Customer 22378 arrives
#     276.21: ####################################
#     276.63: Customer 22343 departs
#     276.63: ###################################
#     277.10: Customer 22379 arrives
#     277.10: ####################################
#     277.61: Customer 22380 arrives
#     277.61: #####################################
#     277.63: Customer 22344 departs
#     277.63: ####################################
#     278.63: Customer 22345 departs
#     278.63: ###################################
#     278.97: Customer 22381 arrives
#     278.97: ####################################
#     279.22: Customer 22382 arrives
#     279.22: #####################################
#     279.63: Customer 22346 departs
#     279.63: ####################################
#     280.63: Customer 22347 departs
#     280.63: ###################################
#     281.63: Customer 22348 departs
#     281.63: ##################################
#     281.95: Customer 22383 arrives
#     281.95: ###################################
#     282.63: Customer 22349 departs
#     282.63: ##################################
#     283.50: Customer 22384 arrives
#     283.50: ###################################
#     283.63: Customer 22350 departs
#     283.63: ##################################
#     284.41: Customer 22385 arrives
#     284.41: ###################################
#     284.63: Customer 22351 departs
#     284.63: ##################################
#     285.63: Customer 22352 departs
#     285.63: #################################
#     285.70: Customer 22386 arrives
#     285.70: ##################################
#     286.36: Customer 22387 arrives
#     286.36: ###################################
#     286.49: Customer 22388 arrives
#     286.49: ####################################
#     286.63: Customer 22353 departs
#     286.63: ###################################
#     287.44: Customer 22389 arrives
#     287.44: ####################################
#     287.63: Customer 22354 departs
#     287.63: ###################################
#     287.69: Customer 22390 arrives
#     287.69: ####################################
#     288.63: Customer 22355 departs
#     288.63: ###################################
#     289.63: Customer 22356 departs
#     289.63: ##################################
#     289.65: Customer 22391 arrives
#     289.65: ###################################
#     290.63: Customer 22357 departs
#     290.63: ##################################
#     291.63: Customer 22358 departs
#     291.63: #################################
#     292.18: Customer 22392 arrives
#     292.18: ##################################
#     292.63: Customer 22359 departs
#     292.63: #################################
#     292.82: Customer 22393 arrives
#     292.82: ##################################
#     293.63: Customer 22360 departs
#     293.63: #################################
#     294.17: Customer 22394 arrives
#     294.17: ##################################
#     294.21: Customer 22395 arrives
#     294.21: ###################################
#     294.63: Customer 22361 departs
#     294.63: ##################################
#     295.25: Customer 22396 arrives
#     295.25: ###################################
#     295.63: Customer 22362 departs
#     295.63: ##################################
#     296.63: Customer 22363 departs
#     296.63: #################################
#     297.63: Customer 22364 departs
#     297.63: ################################
#     298.43: Customer 22397 arrives
#     298.43: #################################
#     298.63: Customer 22365 departs
#     298.63: ################################
#     299.63: Customer 22366 departs
#     299.63: ###############################
#     300.61: Customer 22398 arrives
#     300.61: ################################
#     300.63: Customer 22367 departs
#     300.63: ###############################
#     300.86: Customer 22399 arrives
#     300.86: ################################
#     301.35: Customer 22400 arrives
#     301.35: #################################
#     301.45: Customer 22401 arrives
#     301.45: ##################################
#     301.63: Customer 22368 departs
#     301.63: #################################
#     302.17: Customer 22402 arrives
#     302.17: ##################################
#     302.63: Customer 22369 departs
#     302.63: #################################
#     303.63: Customer 22370 departs
#     303.63: ################################
#     303.71: Customer 22403 arrives
#     303.71: #################################
#     303.84: Customer 22404 arrives
#     303.84: ##################################
#     304.63: Customer 22371 departs
#     304.63: #################################
#     304.79: Customer 22405 arrives
#     304.79: ##################################
#     305.35: Customer 22406 arrives
#     305.35: ###################################
#     305.63: Customer 22372 departs
#     305.63: ##################################
#     306.63: Customer 22373 departs
#     306.63: #################################
#     306.69: Customer 22407 arrives
#     306.69: ##################################
#     307.63: Customer 22374 departs
#     307.63: #################################
#     308.28: Customer 22408 arrives
#     308.28: ##################################
#     308.63: Customer 22375 departs
#     308.63: #################################
#     309.63: Customer 22376 departs
#     309.63: ################################
#     309.63: Customer 22409 arrives
#     309.63: #################################
#     310.38: Customer 22410 arrives
#     310.38: ##################################
#     310.63: Customer 22377 departs
#     310.63: #################################
#     311.06: Customer 22411 arrives
#     311.06: ##################################
#     311.63: Customer 22378 departs
#     311.63: #################################
#     312.63: Customer 22379 departs
#     312.63: ################################
#     313.63: Customer 22380 departs
#     313.63: ###############################
#     313.75: Customer 22412 arrives
#     313.75: ################################
#     313.96: Customer 22413 arrives
#     313.96: #################################
#     314.63: Customer 22381 departs
#     314.63: ################################
#     315.53: Customer 22414 arrives
#     315.53: #################################
#     315.63: Customer 22382 departs
#     315.63: ################################
#     316.63: Customer 22383 departs
#     316.63: ###############################
#     316.84: Customer 22415 arrives
#     316.84: ################################
#     316.90: Customer 22416 arrives
#     316.90: #################################
#     317.63: Customer 22384 departs
#     317.63: ################################
#     317.87: Customer 22417 arrives
#     317.87: #################################
#     317.88: Customer 22418 arrives
#     317.88: ##################################
#     318.31: Customer 22419 arrives
#     318.31: ###################################
#     318.63: Customer 22385 departs
#     318.63: ##################################
#     319.63: Customer 22386 departs
#     319.63: #################################
#     320.63: Customer 22387 departs
#     320.63: ################################
#     321.26: Customer 22420 arrives
#     321.26: #################################
#     321.63: Customer 22388 departs
#     321.63: ################################
#     322.30: Customer 22421 arrives
#     322.30: #################################
#     322.63: Customer 22389 departs
#     322.63: ################################
#     322.78: Customer 22422 arrives
#     322.78: #################################
#     323.63: Customer 22390 departs
#     323.63: ################################
#     323.83: Customer 22423 arrives
#     323.83: #################################
#     323.85: Customer 22424 arrives
#     323.85: ##################################
#     323.99: Customer 22425 arrives
#     323.99: ###################################
#     324.04: Customer 22426 arrives
#     324.04: ####################################
#     324.63: Customer 22391 departs
#     324.63: ###################################
#     325.38: Customer 22427 arrives
#     325.38: ####################################
#     325.50: Customer 22428 arrives
#     325.50: #####################################
#     325.63: Customer 22392 departs
#     325.63: ####################################
#     326.08: Customer 22429 arrives
#     326.08: #####################################
#     326.26: Customer 22430 arrives
#     326.26: ######################################
#     326.63: Customer 22393 departs
#     326.63: #####################################
#     326.95: Customer 22431 arrives
#     326.95: ######################################
#     327.24: Customer 22432 arrives
#     327.24: #######################################
#     327.63: Customer 22394 departs
#     327.63: ######################################
#     328.12: Customer 22433 arrives
#     328.12: #######################################
#     328.63: Customer 22395 departs
#     328.63: ######################################
#     329.63: Customer 22396 departs
#     329.63: #####################################
#     329.86: Customer 22434 arrives
#     329.86: ######################################
#     329.98: Customer 22435 arrives
#     329.98: #######################################
#     330.43: Customer 22436 arrives
#     330.43: ########################################
#     330.63: Customer 22397 departs
#     330.63: #######################################
#     331.21: Customer 22437 arrives
#     331.21: ########################################
#     331.63: Customer 22398 departs
#     331.63: #######################################
#     332.40: Customer 22438 arrives
#     332.40: ########################################
#     332.41: Customer 22439 arrives
#     332.41: #########################################
#     332.63: Customer 22399 departs
#     332.63: ########################################
#     333.63: Customer 22400 departs
#     333.63: #######################################
#     334.63: Customer 22401 departs
#     334.63: ######################################
#     334.85: Customer 22440 arrives
#     334.85: #######################################
#     335.63: Customer 22402 departs
#     335.63: ######################################
#     336.17: Customer 22441 arrives
#     336.17: #######################################
#     336.41: Customer 22442 arrives
#     336.41: ########################################
#     336.63: Customer 22403 departs
#     336.63: #######################################
#     336.81: Customer 22443 arrives
#     336.81: ########################################
#     337.00: Customer 22444 arrives
#     337.00: #########################################
#     337.63: Customer 22404 departs
#     337.63: ########################################
#     338.63: Customer 22405 departs
#     338.63: #######################################
#     339.59: Customer 22445 arrives
#     339.59: ########################################
#     339.63: Customer 22406 departs
#     339.63: #######################################
#     339.70: Customer 22446 arrives
#     339.70: ########################################
#     340.24: Customer 22447 arrives
#     340.24: #########################################
#     340.63: Customer 22407 departs
#     340.63: ########################################
#     341.16: Customer 22448 arrives
#     341.16: #########################################
#     341.63: Customer 22408 departs
#     341.63: ########################################
#     341.88: Customer 22449 arrives
#     341.88: #########################################
#     341.94: Customer 22450 arrives
# ...
#     941.89: Customer 33044 arrives
#     941.89: #######################################################################
#     942.12: Customer 32974 departs
#     942.12: ######################################################################
#     942.64: Customer 33045 arrives
#     942.64: #######################################################################
#     942.75: Customer 33046 arrives
#     942.75: ########################################################################
#     942.89: Customer 33047 arrives
#     942.89: #########################################################################
#     943.12: Customer 32975 departs
#     943.12: ########################################################################
#     943.36: Customer 33048 arrives
#     943.36: #########################################################################
#     944.12: Customer 32976 departs
#     944.12: ########################################################################
#     944.42: Customer 33049 arrives
#     944.42: #########################################################################
#     944.94: Customer 33050 arrives
#     944.94: ##########################################################################
#     945.12: Customer 32977 departs
#     945.12: #########################################################################
#     945.36: Customer 33051 arrives
#     945.36: ##########################################################################
#     945.53: Customer 33052 arrives
#     945.53: ###########################################################################
#     946.12: Customer 32978 departs
#     946.12: ##########################################################################
#     946.46: Customer 33053 arrives
#     946.46: ###########################################################################
#     947.12: Customer 32979 departs
#     947.12: ##########################################################################
#     947.95: Customer 33054 arrives
#     947.95: ###########################################################################
#     948.12: Customer 32980 departs
#     948.12: ##########################################################################
#     949.12: Customer 32981 departs
#     949.12: #########################################################################
#     949.85: Customer 33055 arrives
#     949.85: ##########################################################################
#     950.12: Customer 32982 departs
#     950.12: #########################################################################
#     950.74: Customer 33056 arrives
#     950.74: ##########################################################################
#     950.93: Customer 33057 arrives
#     950.93: ###########################################################################
#     951.12: Customer 32983 departs
#     951.12: ##########################################################################
#     951.54: Customer 33058 arrives
#     951.54: ###########################################################################
#     952.12: Customer 32984 departs
#     952.12: ##########################################################################
#     952.16: Customer 33059 arrives
#     952.16: ###########################################################################
#     952.16: Customer 33060 arrives
#     952.16: ############################################################################
#     952.54: Customer 33061 arrives
#     952.54: #############################################################################
#     953.02: Customer 33062 arrives
#     953.02: ##############################################################################
#     953.12: Customer 32985 departs
#     953.12: #############################################################################
#     953.38: Customer 33063 arrives
#     953.38: ##############################################################################
#     953.39: Customer 33064 arrives
#     953.39: ###############################################################################
#     953.64: Customer 33065 arrives
#     953.64: ################################################################################
#     954.12: Customer 32986 departs
#     954.12: ###############################################################################
#     955.12: Customer 32987 departs
#     955.12: ##############################################################################
#     955.42: Customer 33066 arrives
#     955.42: ###############################################################################
#     956.12: Customer 32988 departs
#     956.12: ##############################################################################
#     956.16: Customer 33067 arrives
#     956.16: ###############################################################################
#     957.12: Customer 32989 departs
#     957.12: ##############################################################################
#     957.49: Customer 33068 arrives
#     957.49: ###############################################################################
#     957.63: Customer 33069 arrives
#     957.63: ################################################################################
#     958.05: Customer 33070 arrives
#     958.05: #################################################################################
#     958.07: Customer 33071 arrives
#     958.07: ##################################################################################
#     958.12: Customer 32990 departs
#     958.12: #################################################################################
#     958.99: Customer 33072 arrives
#     958.99: ##################################################################################
#     959.12: Customer 32991 departs
#     959.12: #################################################################################
#     959.18: Customer 33073 arrives
#     959.18: ##################################################################################
#     959.60: Customer 33074 arrives
#     959.60: ###################################################################################
#     960.12: Customer 32992 departs
#     960.12: ##################################################################################
#     961.12: Customer 32993 departs
#     961.12: #################################################################################
#     961.45: Customer 33075 arrives
#     961.45: ##################################################################################
#     962.12: Customer 32994 departs
#     962.12: #################################################################################
#     963.12: Customer 32995 departs
#     963.12: ################################################################################
#     963.72: Customer 33076 arrives
#     963.72: #################################################################################
#     964.12: Customer 32996 departs
#     964.12: ################################################################################
#     965.12: Customer 32997 departs
#     965.12: ###############################################################################
#     965.97: Customer 33077 arrives
#     965.97: ################################################################################
#     966.12: Customer 32998 departs
#     966.12: ###############################################################################
#     966.39: Customer 33078 arrives
#     966.39: ################################################################################
#     966.47: Customer 33079 arrives
#     966.47: #################################################################################
#     967.12: Customer 32999 departs
#     967.12: ################################################################################
#     967.17: Customer 33080 arrives
#     967.17: #################################################################################
#     968.12: Customer 33000 departs
#     968.12: ################################################################################
#     969.12: Customer 33001 departs
#     969.12: ###############################################################################
#     970.12: Customer 33002 departs
#     970.12: ##############################################################################
#     970.36: Customer 33081 arrives
#     970.36: ###############################################################################
#     971.12: Customer 33003 departs
#     971.12: ##############################################################################
#     972.12: Customer 33004 departs
#     972.12: #############################################################################
#     972.27: Customer 33082 arrives
#     972.27: ##############################################################################
#     972.88: Customer 33083 arrives
#     972.88: ###############################################################################
#     973.12: Customer 33005 departs
#     973.12: ##############################################################################
#     974.12: Customer 33006 departs
#     974.12: #############################################################################
#     975.12: Customer 33007 departs
#     975.12: ############################################################################
#     976.05: Customer 33084 arrives
#     976.05: #############################################################################
#     976.12: Customer 33008 departs
#     976.12: ############################################################################
#     976.30: Customer 33085 arrives
#     976.30: #############################################################################
#     976.69: Customer 33086 arrives
#     976.69: ##############################################################################
#     977.12: Customer 33009 departs
#     977.12: #############################################################################
#     977.17: Customer 33087 arrives
#     977.17: ##############################################################################
#     977.31: Customer 33088 arrives
#     977.31: ###############################################################################
#     978.12: Customer 33010 departs
#     978.12: ##############################################################################
#     979.12: Customer 33011 departs
#     979.12: #############################################################################
#     980.12: Customer 33012 departs
#     980.12: ############################################################################
#     980.83: Customer 33089 arrives
#     980.83: #############################################################################
#     980.93: Customer 33090 arrives
#     980.93: ##############################################################################
#     981.12: Customer 33013 departs
#     981.12: #############################################################################
#     982.12: Customer 33014 departs
#     982.12: ############################################################################
#     982.54: Customer 33091 arrives
#     982.54: #############################################################################
#     983.05: Customer 33092 arrives
#     983.05: ##############################################################################
#     983.12: Customer 33015 departs
#     983.12: #############################################################################
#     983.22: Customer 33093 arrives
#     983.22: ##############################################################################
#     984.12: Customer 33016 departs
#     984.12: #############################################################################
#     984.16: Customer 33094 arrives
#     984.16: ##############################################################################
#     985.12: Customer 33017 departs
#     985.12: #############################################################################
#     985.78: Customer 33095 arrives
#     985.78: ##############################################################################
#     985.81: Customer 33096 arrives
#     985.81: ###############################################################################
#     986.12: Customer 33018 departs
#     986.12: ##############################################################################
#     987.12: Customer 33019 departs
#     987.12: #############################################################################
#     987.51: Customer 33097 arrives
#     987.51: ##############################################################################
#     987.72: Customer 33098 arrives
#     987.72: ###############################################################################
#     988.12: Customer 33020 departs
#     988.12: ##############################################################################
#     989.12: Customer 33021 departs
#     989.12: #############################################################################
#     990.12: Customer 33022 departs
#     990.12: ############################################################################
#     991.12: Customer 33023 departs
#     991.12: ###########################################################################
#     991.59: Customer 33099 arrives
#     991.59: ############################################################################
#     992.12: Customer 33024 departs
#     992.12: ###########################################################################
#     992.64: Customer 33100 arrives
#     992.64: ############################################################################
#     992.84: Customer 33101 arrives
#     992.84: #############################################################################
#     992.95: Customer 33102 arrives
#     992.95: ##############################################################################
#     993.04: Customer 33103 arrives
#     993.04: ###############################################################################
#     993.12: Customer 33025 departs
#     993.12: ##############################################################################
#     993.58: Customer 33104 arrives
#     993.58: ###############################################################################
#     993.83: Customer 33105 arrives
#     993.83: ################################################################################
#     994.12: Customer 33106 arrives
#     994.12: #################################################################################
#     994.12: Customer 33026 departs
#     994.12: ################################################################################
#     994.54: Customer 33107 arrives
#     994.54: #################################################################################
#     995.12: Customer 33027 departs
#     995.12: ################################################################################
#     996.08: Customer 33108 arrives
#     996.08: #################################################################################
#     996.12: Customer 33028 departs
#     996.12: ################################################################################
#     997.12: Customer 33109 arrives
#     997.12: #################################################################################
#     997.12: Customer 33029 departs
#     997.12: ################################################################################
#     998.05: Customer 33110 arrives
#     998.05: #################################################################################
#     998.12: Customer 33030 departs
#     998.12: ################################################################################
#     998.58: Customer 33111 arrives
#     998.58: #################################################################################
#     999.12: Customer 33031 departs
#     999.12: ################################################################################
#     999.46: Customer 33112 arrives
#     999.46: #################################################################################
# 1000 1.1 56.568179651 1314.60665601

# %%
np.var(full_L_array)
# Out:
# 1314.6066560073937
